# %% [markdown]
# # 【第1回_Beginner限定コンペ】銀行の顧客ターゲティング
#
# 顧客の属性情報などから定期預金キャンペーンの反応率を予測しよう。
#
# https://signate.jp/competitions/292
#
# LightGBM編

# %% [markdown]
# ## ライブラリインポート

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import lightgbm as lgb
from optuna.integration import lightgbm as optuna_lgb
#import featuretools as ft

#from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_curve, auc

# %% [markdown]
# ## データ読み込み・前処理

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# 練習コンペのデータ
train_practice_df = pd.read_csv('train_practice.csv')
test_practice_df = pd.read_csv('test_practice.csv')

# オリジナルデータ
train_org_df = pd.read_csv('bank-full.csv', sep=';')

# Pseudo Labeling
test_p1_df = pd.read_csv('test_p1.csv')

# poutcome の前処理済みファイルを使う
#train_df = pd.read_csv('y_train-Copy1.csv')
#test_df = pd.read_csv('y_test-Copy1.csv')
#train2_df = pd.read_csv('y_train-Copy2.csv')
#test2_df = pd.read_csv('y_test-Copy2.csv')
#train3_df = pd.read_csv('y_train-Copy3.csv')
#test3_df = pd.read_csv('y_test-Copy3.csv')

submit_df = pd.read_csv('submit_sample.csv', header=None)

# %%
print(train_df.shape)
print(test_df.shape)
print(test_p1_df.shape)
print(train_practice_df.shape)
print(test_practice_df.shape)
print(train_org_df.shape)
# Out:
# (27100, 18)
# (18050, 17)
# (18050, 15)
# (27128, 18)
# (18083, 17)
# (45211, 17)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27100 entries, 0 to 27099
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         27100 non-null  int64
#  1   age        27100 non-null  int64
#  2   job        27100 non-null  object
#  3   marital    27100 non-null  object
#  4   education  27100 non-null  object
#  5   default    27100 non-null  object
#  6   balance    27100 non-null  int64
#  7   housing    27100 non-null  object
#  8   loan       27100 non-null  object
#  9   contact    27100 non-null  object
#  10  day        27100 non-null  int64
#  11  month      27100 non-null  object
#  12  duration   27100 non-null  int64
#  13  campaign   27100 non-null  int64
#  14  pdays      27100 non-null  int64
#  15  previous   27100 non-null  int64
#  16  poutcome   27100 non-null  object
#  17  y          27100 non-null  int64
# dtypes: int64(9), object(9)
# memory usage: 3.7+ MB

# %%
train_org_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
train_df['poutcome'].value_counts()
# Out:
# unknown    23099
# failure     2717
# other        826
# success      458
# Name: poutcome, dtype: int64

# %%
train_df['y'].value_counts()
# Out:
# 0    24988
# 1     2112
# Name: y, dtype: int64

# %%
train_df.head()
# Out:
#    id  age           job  marital  education default  balance housing loan  \
# 0   0   31      services  married  secondary      no    12294     yes   no
# 1   1   29  entrepreneur   single   tertiary      no    43027      no   no
# 2   2   35    management  married   tertiary      no    12252     yes   no
# 3   3   31    technician  married  secondary      no    99121     yes  yes
# 4   4   48    unemployed  married    primary      no    42005     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome  y
# 0   cellular   21   nov       101         3    498         0    other  0
# 1   cellular   22   aug       158         2    702         0  unknown  1
# 2   cellular   11   nov       351         1    826         0  failure  0
# 3    unknown   16   may       658         2    120         0  failure  0
# 4  telephone    3   apr       177         1    273         0  unknown  0

# %%
test_df.head()
# Out:
#    id  age         job  marital  education default  balance housing loan  \
# 0   0   35  technician   single  secondary      no    89043      no   no
# 1   1   37    services  married  secondary      no    64372     yes   no
# 2   2   31    services   single  secondary      no    31606     yes   no
# 3   3   31      admin.  married  secondary      no    94826     yes   no
# 4   4   32    services  married  secondary      no   100401      no   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome
# 0  cellular    7   feb       101         2    184         2  success
# 1  cellular    7   jul       158         3    241         0  unknown
# 2   unknown   15   may       152         2     47         0  unknown
# 3  cellular   27   may       345         2    490         0  unknown
# 4  cellular    7   jan       126         1    686         0    other

# %%
train_df.describe()
# Out:
#                  id           age        balance           day      duration  \
# count  27100.000000  27100.000000   27100.000000  27100.000000  27100.000000
# mean   13549.500000     36.073284   47682.901771     16.700443    229.325387
# std     7823.240484      7.816417   31650.760036      8.576252    204.939958
# min        0.000000     22.000000   -6847.000000      1.000000      0.000000
# 25%     6774.750000     31.000000   20015.750000      8.000000    121.000000
# 50%    13549.500000     33.000000   47624.000000     17.000000    158.000000
# 75%    20324.250000     37.000000   75330.000000     26.000000    345.000000
# max    27099.000000     90.000000  102121.000000     31.000000   3076.000000
#
#            campaign         pdays      previous             y
# count  27100.000000  27100.000000  27100.000000  27100.000000
# mean       1.775830    432.482399      0.085720      0.077934
# std        0.950045    252.150648      0.365889      0.268072
# min        1.000000     -1.000000      0.000000      0.000000
# 25%        1.000000    214.000000      0.000000      0.000000
# 50%        1.000000    432.000000      0.000000      0.000000
# 75%        2.000000    650.000000      0.000000      0.000000
# max        5.000000    870.000000      3.000000      1.000000

# %%
train_practice_df.describe()
# Out:
#                  id           age        balance           day      duration  \
# count  27128.000000  27128.000000   27128.000000  27128.000000  27128.000000
# mean   13564.500000     40.951010    1355.800870     15.806215    260.711295
# std     7831.323388     10.608542    3003.305272      8.337904    260.091727
# min        1.000000     18.000000   -6847.000000      1.000000      0.000000
# 25%     6782.750000     33.000000      72.000000      8.000000    104.000000
# 50%    13564.500000     39.000000     449.000000     16.000000    182.000000
# 75%    20346.250000     48.000000    1428.000000     21.000000    323.000000
# max    27128.000000     95.000000  102127.000000     31.000000   4918.000000
#
#            campaign         pdays      previous             y
# count  27128.000000  27128.000000  27128.000000  27128.000000
# mean       2.751769     40.528052      0.579733      0.117001
# std        3.126594    100.382462      2.503653      0.321427
# min        1.000000     -1.000000      0.000000      0.000000
# 25%        1.000000     -1.000000      0.000000      0.000000
# 50%        2.000000     -1.000000      0.000000      0.000000
# 75%        3.000000     -1.000000      0.000000      0.000000
# max       63.000000    871.000000    275.000000      1.000000

# %%
test_df.describe()
# Out:
#                  id           age        balance           day      duration  \
# count  18050.000000  18050.000000   18050.000000  18050.000000  18050.000000
# mean    9024.500000     36.104266   47158.451801     16.697950    229.315014
# std     5210.730515      7.863805   31469.525699      8.580203    208.796946
# min        0.000000     20.000000   -6838.000000      1.000000      0.000000
# 25%     4512.250000     31.000000   19654.500000      8.000000    121.000000
# 50%     9024.500000     33.000000   46886.000000     17.000000    158.000000
# 75%    13536.750000     37.000000   74178.000000     26.000000    345.000000
# max    18049.000000     90.000000  102124.000000     31.000000   3076.000000
#
#            campaign         pdays      previous
# count  18050.000000  18050.000000  18050.000000
# mean       1.770083    436.171801      0.090859
# std        0.944872    251.392519      0.375801
# min        1.000000     -1.000000      0.000000
# 25%        1.000000    219.250000      0.000000
# 50%        1.000000    436.000000      0.000000
# 75%        2.000000    654.000000      0.000000
# max        4.000000    870.000000      3.000000

# %%
train_df.isnull().any()
# Out:
# id           False
# age          False
# job          False
# marital      False
# education    False
# default      False
# balance      False
# housing      False
# loan         False
# contact      False
# day          False
# month        False
# duration     False
# campaign     False
# pdays        False
# previous     False
# poutcome     False
# y            False
# dtype: bool

# %%
test_df.isnull().any()
# Out:
# id           False
# age          False
# job          False
# marital      False
# education    False
# default      False
# balance      False
# housing      False
# loan         False
# contact      False
# day          False
# month        False
# duration     False
# campaign     False
# pdays        False
# previous     False
# poutcome     False
# dtype: bool

# %%
# job のラベリングを y の平均の低い順にしてみる
#train_df.groupby('job').mean().sort_values('y')

# %%
train_df.drop(['id'], axis=1, inplace=True)
test_df.drop(['id'], axis=1, inplace=True)

train_org_df['y'] = train_org_df['y'].map(dict(yes=1, no=0))

#train_df = pd.concat([train_df, train_org_df])

# %%
merge_df = pd.concat([train_df, test_df])

df_dict = {}
for name, group in merge_df.groupby('poutcome'):
    df_dict[name] = group
    
p_train_df = pd.concat([df_dict['success'], df_dict['failure'], df_dict['other']])
p_test_df = df_dict['unknown']

py = p_train_df.pop('y')
pz = p_test_df.pop('y')

# %% [markdown]
# データメモ
#
# - testデータの `job` に `unknown` が一人いる (trainデータにはいない)

# %%
# one hot encoding
#train_df = pd.get_dummies(train_df, columns=['job', 'marital', 'education', 'contact', 'poutcome'])
#test_df = pd.get_dummies(test_df, columns=['job', 'marital', 'education', 'contact', 'poutcome'])
#test_df.drop(['job_unknown'], axis=1, inplace=True)

df_list = [p_train_df, p_test_df]

#train_df['poutcome'] = (train_df['poutcome'] + train2_df['poutcome'] + train3_df['poutcome']) / 3
#test_df['poutcome'] = (test_df['poutcome'] + test2_df['poutcome'] + test3_df['poutcome']) / 3

#job_encoder = LabelEncoder()
#job_encoder.fit(test_df['job'])

#job_label_mean = train_df.groupby('job')['y'].mean()

for df in df_list:
    #df['job'] = job_encoder.transform(df['job'])
    df['job'] = df['job'].map({'unknown': 1, 'technician': 2, 'blue-collar': 3, 'services': 4, 'entrepreneur': 5, 'admin.': 6, 'management': 7, 'housemaid': 8, 'self-employed': 9, 'unemployed': 10, 'retired': 11, 'student': 12})

    # Target Mean Encoding
    #df['target_job'] = df['job'].map(job_label_mean)
    #df.drop(['job'], axis=1, inplace=True)

    df['marital'] = df['marital'].map({'married': 2, 'divorced':1, 'single': 0})
    #df.drop(['marital'], axis=1, inplace=True)

    df['education'] = df['education'].map({'tertiary': 3, 'secondary': 2, 'primary': 1, 'unknown': 0})
    #df.drop(['education'], axis=1, inplace=True)

    #df['default'] = df['default'].map({'yes': 1, 'no': 0})
    df.drop(['default'], axis=1, inplace=True)

    df['housing'] = df['housing'].map({'yes': 1, 'no': 0})
    #df.drop(['housing'], axis=1, inplace=True)
    
    df['loan'] = df['loan'].map({'yes': 1, 'no': 0})
    #df.drop(['loan'], axis=1, inplace=True)

    df['contact'] = df['contact'].map({'telephone': 2, 'cellular': 1, 'unknown': 0})
    #df.drop(['contact'], axis=1, inplace=True)

    df['poutcome'] = df['poutcome'].map({'success': 1, 'unknown': 99, 'failure': 0, 'other': 0})
    
    df['month'] = df['month'].map({'jan': 1, 'feb': 2, 'mar': 3, 'apr': 4, 'may': 5, 'jun': 6, 'jul': 7, 'aug': 8, 'sep': 9, 'oct': 10, 'nov': 11, 'dec': 12})
    #df.drop(['day', 'month'], axis=1, inplace=True)
    
    # Feb 30 とかあって、正確には変換できない
    # → データの Feb 30 を Mar 1 に変換した(他にも、 2/31, 6/31, 11/31)
    df['days'] = pd.to_datetime('2016/' + df['month'].astype(str).str.pad(2,fillchar='0') + '/' + df['day'].astype(str).str.pad(2,fillchar='0'), format='%Y/%m/%d').dt.strftime('%j').astype('uint16')
    #df['days'] = df['month'] * 31 + df['day']
    
    #df['duration'] = np.log(df['duration'] + 1)
    #df['bpp'] = np.log((df['balance'] - df['balance'].min()) / (df['pdays'] + 2) + 1)
    
    #df.drop(['id'], axis=1, inplace=True)
    
    df.drop(['pdays'], axis=1, inplace=True)
    df.drop(['balance'], axis=1, inplace=True)
    
# featuretools用
#y = train_df.pop('y')
#train_df['train'] = 1
#test_df['train'] = 0
#test_df['id'] = test_df['id'] + len(train_df)

# %%
# Pseudo Labeling
#train_df = pd.concat([train_df, test_p1_df])

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27100 entries, 0 to 27099
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        27100 non-null  int64
#  1   job        27100 non-null  object
#  2   marital    27100 non-null  object
#  3   education  27100 non-null  object
#  4   default    27100 non-null  object
#  5   balance    27100 non-null  int64
#  6   housing    27100 non-null  object
#  7   loan       27100 non-null  object
#  8   contact    27100 non-null  object
#  9   day        27100 non-null  int64
#  10  month      27100 non-null  object
#  11  duration   27100 non-null  int64
#  12  campaign   27100 non-null  int64
#  13  pdays      27100 non-null  int64
#  14  previous   27100 non-null  int64
#  15  poutcome   27100 non-null  object
#  16  y          27100 non-null  int64
# dtypes: int64(8), object(9)
# memory usage: 3.5+ MB

# %%
train_df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   31      services  married  secondary      no    12294     yes   no
# 1   29  entrepreneur   single   tertiary      no    43027      no   no
# 2   35    management  married   tertiary      no    12252     yes   no
# 3   31    technician  married  secondary      no    99121     yes  yes
# 4   48    unemployed  married    primary      no    42005     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome  y
# 0   cellular   21   nov       101         3    498         0    other  0
# 1   cellular   22   aug       158         2    702         0  unknown  1
# 2   cellular   11   nov       351         1    826         0  failure  0
# 3    unknown   16   may       658         2    120         0  failure  0
# 4  telephone    3   apr       177         1    273         0  unknown  0

# %%
test_df.head()
# Out:
#    age         job  marital  education default  balance housing loan  \
# 0   35  technician   single  secondary      no    89043      no   no
# 1   37    services  married  secondary      no    64372     yes   no
# 2   31    services   single  secondary      no    31606     yes   no
# 3   31      admin.  married  secondary      no    94826     yes   no
# 4   32    services  married  secondary      no   100401      no   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome
# 0  cellular    7   feb       101         2    184         2  success
# 1  cellular    7   jul       158         3    241         0  unknown
# 2   unknown   15   may       152         2     47         0  unknown
# 3  cellular   27   may       345         2    490         0  unknown
# 4  cellular    7   jan       126         1    686         0    other

# %%
train_df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  27100.000000   27100.000000  27100.000000  27100.000000  27100.000000
# mean      36.073284   47682.901771     16.700443    229.325387      1.775830
# std        7.816417   31650.760036      8.576252    204.939958      0.950045
# min       22.000000   -6847.000000      1.000000      0.000000      1.000000
# 25%       31.000000   20015.750000      8.000000    121.000000      1.000000
# 50%       33.000000   47624.000000     17.000000    158.000000      1.000000
# 75%       37.000000   75330.000000     26.000000    345.000000      2.000000
# max       90.000000  102121.000000     31.000000   3076.000000      5.000000
#
#               pdays      previous             y
# count  27100.000000  27100.000000  27100.000000
# mean     432.482399      0.085720      0.077934
# std      252.150648      0.365889      0.268072
# min       -1.000000      0.000000      0.000000
# 25%      214.000000      0.000000      0.000000
# 50%      432.000000      0.000000      0.000000
# 75%      650.000000      0.000000      0.000000
# max      870.000000      3.000000      1.000000

# %%
test_df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  18050.000000   18050.000000  18050.000000  18050.000000  18050.000000
# mean      36.104266   47158.451801     16.697950    229.315014      1.770083
# std        7.863805   31469.525699      8.580203    208.796946      0.944872
# min       20.000000   -6838.000000      1.000000      0.000000      1.000000
# 25%       31.000000   19654.500000      8.000000    121.000000      1.000000
# 50%       33.000000   46886.000000     17.000000    158.000000      1.000000
# 75%       37.000000   74178.000000     26.000000    345.000000      2.000000
# max       90.000000  102124.000000     31.000000   3076.000000      4.000000
#
#               pdays      previous
# count  18050.000000  18050.000000
# mean     436.171801      0.090859
# std      251.392519      0.375801
# min       -1.000000      0.000000
# 25%      219.250000      0.000000
# 50%      436.000000      0.000000
# 75%      654.000000      0.000000
# max      870.000000      3.000000

# %%
# featuretools による総当り特徴量生成

#df = pd.concat([train_df, test_df])

#es = ft.EntitySet(id='bank')
#es.entity_from_dataframe(entity_id='bank', dataframe=df, index='id')
#feature_matrix, feature_defs = ft.dfs(
#    entityset=es,
#    target_entity='bank',
#    trans_primitives=['subtract_numeric'],
#    agg_primitives=[],
#    max_depth=1,
#)

#df_dict = {}
#for name, group in feature_matrix.groupby('train'):
#    df_dict[name] = group
    
#train_df = df_dict[1]
#test_df = df_dict[0]

#train_df.drop(['train'], axis=1, inplace=True)
#test_df.drop(['train'], axis=1, inplace=True)

# %%
#train_df.head()

# %%
#test_df.head()

# %%
#train_df.info()

# %%
#train_pg = sns.pairplot(train_df.drop(['month', 'day'], axis=1), hue='y')
#train_pg = sns.pairplot(train_df, hue='y')
#train_pg.savefig('train_df.png')

#test_pg = sns.pairplot(test_df)
#test_pg.savefig('test_df.png')

# %%
class TunerCVCheckpointCallback(object):
    """Optuna の LightGBMTunerCV から学習済みモデルを取り出すためのコールバック"""

    def __init__(self):
        # オンメモリでモデルを記録しておく辞書
        self.cv_boosters = {}
        self.cv_score = {}

    @staticmethod
    def params_to_hash(params):
        """パラメータを元に辞書のキーとなるハッシュを計算する"""
        params_hash = hash(frozenset(params.items()))
        return params_hash

    def get_trained_model(self, params):
        """パラメータをキーとして学習済みモデルを取り出す"""
        params_hash = self.params_to_hash(params)
        return self.cv_boosters[params_hash]

    def __call__(self, env):
        """LightGBM の各ラウンドで呼ばれるコールバック"""
        # 学習に使うパラメータをハッシュ値に変換する
        params_hash = self.params_to_hash(env.params)
        # 初登場のパラメータならモデルへの参照を保持する
        #if params_hash not in self.cv_boosters:
        #    self.cv_boosters[params_hash] = env.model
        
        # 保存済みのパラメータよりスコアが良ければモデルを保存する
        score = env.evaluation_result_list[0][2]
        if (
            params_hash not in self.cv_score
            or score > self.cv_score[params_hash]
        ):
            self.cv_score[params_hash] = score
            self.cv_boosters[params_hash] = env.model

# %% [markdown]
# ## 学習準備

# %%
#y = train_df.pop('y')
y = p_train_df.pop('poutcome')
z = p_test_df.pop('poutcome')

#X_train, X_test, y_train, y_test = train_test_split(train_df, y, test_size=0.2, random_state=44)
#X_train, X_test, y_train, y_test = train_test_split(train_df, y, random_state=44)

#train_data = lgb.Dataset(data=X_train, label=y_train, free_raw_data=False)
#test_data = lgb.Dataset(data=X_test, label=y_test, free_raw_data=False)
final_train_set = lgb.Dataset(data=p_train_df, label=y, free_raw_data=False)

folds = StratifiedKFold(n_splits=3, shuffle=True, random_state=33)

# 学習済みモデルへの参照を保持するためのコールバック
checkpoint_cb = TunerCVCheckpointCallback()
callbacks = [
    checkpoint_cb,
]

# %% [markdown]
# ## ハイパーパラメータ

# %%
lgb_params = {
    'objective': 'binary',     # Binary classification
    'metric': 'auc',  # Area under ROC curve as the evaulation metric
    'random_state': 22,
    'learning_rate': 0.01,
    # 以下はoptunaでチューニングする
    #'learning_rate': 0.05,       # Learning rate, controls size of a gradient descent step
    #'min_data_in_leaf': 20,      # Data set is quite small so reduce this a bit
    #'feature_fraction': 0.7,     # Proportion of features in each boost, controls overfitting
    #'num_leaves': 41,            # Controls size of tree since LGBM uses leaf wise splits
    #'drop_rate': 0.15
}

# %% [markdown]
# ## 学習

# %%
tuner = optuna_lgb.LightGBMTunerCV(
    lgb_params,
    final_train_set,
    num_boost_round=10000,
    early_stopping_rounds=100,
    verbose_eval=0,
    folds=folds,
    callbacks=callbacks,
)
tuner.run()

# NOTE: 念のためハッシュの衝突に備えて Trial の数と学習済みモデルの数を比較しておく
#assert len(checkpoint_cb.cv_boosters) == len(tuner.study.trials) - 1

# 最も良かったパラメータをキーにして学習済みモデルを取り出す
cv_booster = checkpoint_cb.get_trained_model(tuner.best_params)

print("  Params: ")
for key, value in tuner.best_params.items():
    print("    {}: {}".format(key, value))
# Out:
# feature_fraction, val_score: 0.850273:  14%|#4        | 1/7 [00:03<00:18,  3.11s/it][I 2020-08-27 08:41:49,014] Trial 0 finished with value: 0.8502734463293025 and parameters: {'feature_fraction': 1.0}. Best is trial 0 with value: 0.8502734463293025.
# feature_fraction, val_score: 0.860598:  29%|##8       | 2/7 [00:05<00:14,  2.88s/it][I 2020-08-27 08:41:51,359] Trial 1 finished with value: 0.8605981128035026 and parameters: {'feature_fraction': 0.6}. Best is trial 1 with value: 0.8605981128035026.
# feature_fraction, val_score: 0.860598:  43%|####2     | 3/7 [00:07<00:11,  2.77s/it][I 2020-08-27 08:41:53,855] Trial 2 finished with value: 0.8520530164995108 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 1 with value: 0.8605981128035026.
# feature_fraction, val_score: 0.860598:  57%|#####7    | 4/7 [00:10<00:07,  2.65s/it][I 2020-08-27 08:41:56,252] Trial 3 finished with value: 0.8551216271156364 and parameters: {'feature_fraction': 0.8}. Best is trial 1 with value: 0.8605981128035026.
# feature_fraction, val_score: 0.864069:  71%|#######1  | 5/7 [00:12<00:05,  2.56s/it][I 2020-08-27 08:41:58,602] Trial 4 finished with value: 0.8640687408109752 and parameters: {'feature_fraction': 0.5}. Best is trial 4 with value: 0.8640687408109752.
# feature_fraction, val_score: 0.864069:  86%|########5 | 6/7 [00:15<00:02,  2.62s/it][I 2020-08-27 08:42:01,346] Trial 5 finished with value: 0.8572596430485463 and parameters: {'feature_fraction': 0.7}. Best is trial 4 with value: 0.8640687408109752.
# feature_fraction, val_score: 0.870557: 100%|##########| 7/7 [00:17<00:00,  2.33s/it][I 2020-08-27 08:42:02,992] Trial 6 finished with value: 0.8705574271120439 and parameters: {'feature_fraction': 0.4}. Best is trial 6 with value: 0.8705574271120439.
# feature_fraction, val_score: 0.870557: 100%|##########| 7/7 [00:17<00:00,  2.44s/it]
# num_leaves, val_score: 0.870557:   5%|5         | 1/20 [00:02<00:54,  2.85s/it][I 2020-08-27 08:42:05,853] Trial 7 finished with value: 0.8643784278463832 and parameters: {'num_leaves': 240}. Best is trial 7 with value: 0.8643784278463832.
# num_leaves, val_score: 0.870557:  10%|#         | 2/20 [00:05<00:49,  2.75s/it][I 2020-08-27 08:42:08,364] Trial 8 finished with value: 0.8644711243504618 and parameters: {'num_leaves': 118}. Best is trial 8 with value: 0.8644711243504618.
# num_leaves, val_score: 0.870557:  15%|#5        | 3/20 [00:08<00:47,  2.78s/it][I 2020-08-27 08:42:11,195] Trial 9 finished with value: 0.8643784278463832 and parameters: {'num_leaves': 171}. Best is trial 8 with value: 0.8644711243504618.
# num_leaves, val_score: 0.870851:  20%|##        | 4/20 [00:10<00:41,  2.58s/it][I 2020-08-27 08:42:13,329] Trial 10 finished with value: 0.8708514812138276 and parameters: {'num_leaves': 28}. Best is trial 10 with value: 0.8708514812138276.
# num_leaves, val_score: 0.870851:  25%|##5       | 5/20 [00:12<00:36,  2.46s/it][I 2020-08-27 08:42:15,489] Trial 11 finished with value: 0.8684954081441375 and parameters: {'num_leaves': 7}. Best is trial 10 with value: 0.8708514812138276.
# num_leaves, val_score: 0.870851:  30%|###       | 6/20 [00:15<00:37,  2.71s/it][I 2020-08-27 08:42:18,788] Trial 12 finished with value: 0.8683626529109588 and parameters: {'num_leaves': 5}. Best is trial 10 with value: 0.8708514812138276.
# num_leaves, val_score: 0.870851:  35%|###5      | 7/20 [00:19<00:38,  2.93s/it][I 2020-08-27 08:42:22,234] Trial 13 finished with value: 0.8666847870197194 and parameters: {'num_leaves': 78}. Best is trial 10 with value: 0.8708514812138276.
# num_leaves, val_score: 0.870851:  40%|####      | 8/20 [00:21<00:33,  2.75s/it][I 2020-08-27 08:42:24,575] Trial 14 finished with value: 0.8700507709501144 and parameters: {'num_leaves': 47}. Best is trial 10 with value: 0.8708514812138276.
# num_leaves, val_score: 0.870851:  45%|####5     | 9/20 [00:24<00:30,  2.77s/it][I 2020-08-27 08:42:27,368] Trial 15 finished with value: 0.8643784278463832 and parameters: {'num_leaves': 195}. Best is trial 10 with value: 0.8708514812138276.
# num_leaves, val_score: 0.870851:  50%|#####     | 10/20 [00:26<00:26,  2.61s/it][I 2020-08-27 08:42:29,602] Trial 16 finished with value: 0.8679480617802287 and parameters: {'num_leaves': 64}. Best is trial 10 with value: 0.8708514812138276.
# num_leaves, val_score: 0.870851:  55%|#####5    | 11/20 [00:29<00:23,  2.62s/it][I 2020-08-27 08:42:32,255] Trial 17 finished with value: 0.8643014916318036 and parameters: {'num_leaves': 133}. Best is trial 10 with value: 0.8708514812138276.
# num_leaves, val_score: 0.871029:  60%|######    | 12/20 [00:30<00:18,  2.35s/it][I 2020-08-27 08:42:33,986] Trial 18 finished with value: 0.8710286146628586 and parameters: {'num_leaves': 20}. Best is trial 18 with value: 0.8710286146628586.
# num_leaves, val_score: 0.871029:  65%|######5   | 13/20 [00:33<00:17,  2.55s/it][I 2020-08-27 08:42:36,996] Trial 19 finished with value: 0.8681295624744642 and parameters: {'num_leaves': 4}. Best is trial 18 with value: 0.8710286146628586.
# num_leaves, val_score: 0.871029:  70%|#######   | 14/20 [00:36<00:14,  2.44s/it][I 2020-08-27 08:42:39,167] Trial 20 finished with value: 0.8703302640302196 and parameters: {'num_leaves': 38}. Best is trial 18 with value: 0.8710286146628586.
# num_leaves, val_score: 0.871029:  75%|#######5  | 15/20 [00:38<00:11,  2.29s/it][I 2020-08-27 08:42:41,102] Trial 21 finished with value: 0.864957586646503 and parameters: {'num_leaves': 98}. Best is trial 18 with value: 0.8710286146628586.
# num_leaves, val_score: 0.871029:  80%|########  | 16/20 [00:40<00:09,  2.32s/it][I 2020-08-27 08:42:43,485] Trial 22 finished with value: 0.8704572272243453 and parameters: {'num_leaves': 30}. Best is trial 18 with value: 0.8710286146628586.
# num_leaves, val_score: 0.871029:  85%|########5 | 17/20 [00:43<00:07,  2.42s/it][I 2020-08-27 08:42:46,133] Trial 23 finished with value: 0.866638522344973 and parameters: {'num_leaves': 79}. Best is trial 18 with value: 0.8710286146628586.
# num_leaves, val_score: 0.871365:  90%|######### | 18/20 [00:45<00:04,  2.29s/it][I 2020-08-27 08:42:48,130] Trial 24 finished with value: 0.871365325022938 and parameters: {'num_leaves': 24}. Best is trial 24 with value: 0.871365325022938.
# num_leaves, val_score: 0.871365:  95%|#########5| 19/20 [00:47<00:02,  2.22s/it][I 2020-08-27 08:42:50,195] Trial 25 finished with value: 0.8707234965194567 and parameters: {'num_leaves': 26}. Best is trial 24 with value: 0.871365325022938.
# num_leaves, val_score: 0.871365: 100%|##########| 20/20 [00:55<00:00,  3.93s/it][I 2020-08-27 08:42:58,112] Trial 26 finished with value: 0.8620924137740366 and parameters: {'num_leaves': 2}. Best is trial 24 with value: 0.871365325022938.
# num_leaves, val_score: 0.871365: 100%|##########| 20/20 [00:55<00:00,  2.76s/it]
# bagging, val_score: 0.871365:  10%|#         | 1/10 [00:01<00:17,  1.90s/it][I 2020-08-27 08:43:00,020] Trial 27 finished with value: 0.870681620315894 and parameters: {'bagging_fraction': 0.6178014985047284, 'bagging_freq': 5}. Best is trial 27 with value: 0.870681620315894.
# bagging, val_score: 0.871365:  20%|##        | 2/10 [00:03<00:15,  1.93s/it][I 2020-08-27 08:43:02,003] Trial 28 finished with value: 0.8704213473598849 and parameters: {'bagging_fraction': 0.9872767417543054, 'bagging_freq': 1}. Best is trial 27 with value: 0.870681620315894.
# bagging, val_score: 0.871365:  30%|###       | 3/10 [00:06<00:14,  2.05s/it][I 2020-08-27 08:43:04,339] Trial 29 finished with value: 0.8675307563774184 and parameters: {'bagging_fraction': 0.41758202995254307, 'bagging_freq': 7}. Best is trial 27 with value: 0.870681620315894.
# bagging, val_score: 0.871365:  40%|####      | 4/10 [00:08<00:12,  2.05s/it][I 2020-08-27 08:43:06,392] Trial 30 finished with value: 0.8705730308599469 and parameters: {'bagging_fraction': 0.9771480440808593, 'bagging_freq': 1}. Best is trial 27 with value: 0.870681620315894.
# bagging, val_score: 0.871365:  50%|#####     | 5/10 [00:10<00:10,  2.16s/it][I 2020-08-27 08:43:08,815] Trial 31 finished with value: 0.8706254590283812 and parameters: {'bagging_fraction': 0.7646493897307687, 'bagging_freq': 4}. Best is trial 27 with value: 0.870681620315894.
# bagging, val_score: 0.871365:  60%|######    | 6/10 [00:13<00:08,  2.21s/it][I 2020-08-27 08:43:11,144] Trial 32 finished with value: 0.8679758200544271 and parameters: {'bagging_fraction': 0.46580805312956913, 'bagging_freq': 7}. Best is trial 27 with value: 0.870681620315894.
# bagging, val_score: 0.871365:  70%|#######   | 7/10 [00:15<00:06,  2.26s/it][I 2020-08-27 08:43:13,503] Trial 33 finished with value: 0.8703510654897605 and parameters: {'bagging_fraction': 0.810395727353209, 'bagging_freq': 2}. Best is trial 27 with value: 0.870681620315894.
# bagging, val_score: 0.871365:  80%|########  | 8/10 [00:16<00:03,  1.99s/it][I 2020-08-27 08:43:14,879] Trial 34 finished with value: 0.8700102930079264 and parameters: {'bagging_fraction': 0.5640791963312672, 'bagging_freq': 3}. Best is trial 27 with value: 0.870681620315894.
# bagging, val_score: 0.871365:  90%|######### | 9/10 [00:18<00:01,  1.97s/it][I 2020-08-27 08:43:16,790] Trial 35 finished with value: 0.8699741053667687 and parameters: {'bagging_fraction': 0.8943594146451967, 'bagging_freq': 5}. Best is trial 27 with value: 0.870681620315894.
# bagging, val_score: 0.871365: 100%|##########| 10/10 [00:20<00:00,  1.91s/it][I 2020-08-27 08:43:18,568] Trial 36 finished with value: 0.8702235504201775 and parameters: {'bagging_fraction': 0.5909847533587108, 'bagging_freq': 6}. Best is trial 27 with value: 0.870681620315894.
# bagging, val_score: 0.871365: 100%|##########| 10/10 [00:20<00:00,  2.05s/it]
# feature_fraction_stage2, val_score: 0.871365:  33%|###3      | 1/3 [00:01<00:03,  1.96s/it][I 2020-08-27 08:43:20,529] Trial 37 finished with value: 0.8679925885779345 and parameters: {'feature_fraction': 0.44800000000000006}. Best is trial 37 with value: 0.8679925885779345.
# feature_fraction_stage2, val_score: 0.871365:  67%|######6   | 2/3 [00:03<00:01,  1.98s/it][I 2020-08-27 08:43:22,569] Trial 38 finished with value: 0.871365325022938 and parameters: {'feature_fraction': 0.41600000000000004}. Best is trial 38 with value: 0.871365325022938.
# feature_fraction_stage2, val_score: 0.871365: 100%|##########| 3/3 [00:05<00:00,  1.94s/it][I 2020-08-27 08:43:24,429] Trial 39 finished with value: 0.8679925885779345 and parameters: {'feature_fraction': 0.48000000000000004}. Best is trial 38 with value: 0.871365325022938.
# feature_fraction_stage2, val_score: 0.871365: 100%|##########| 3/3 [00:05<00:00,  1.95s/it]
# regularization_factors, val_score: 0.871365:   5%|5         | 1/20 [00:02<00:40,  2.11s/it][I 2020-08-27 08:43:26,545] Trial 40 finished with value: 0.8711647633994498 and parameters: {'lambda_l1': 0.0004526604200978315, 'lambda_l2': 0.015733008829268223}. Best is trial 40 with value: 0.8711647633994498.
# regularization_factors, val_score: 0.871365:  10%|#         | 2/20 [00:04<00:37,  2.08s/it][I 2020-08-27 08:43:28,549] Trial 41 finished with value: 0.8712302959567455 and parameters: {'lambda_l1': 0.0005334205663164064, 'lambda_l2': 0.016664950138305143}. Best is trial 41 with value: 0.8712302959567455.
# regularization_factors, val_score: 0.871365:  15%|#5        | 3/20 [00:06<00:34,  2.05s/it][I 2020-08-27 08:43:30,530] Trial 42 finished with value: 0.871256308394161 and parameters: {'lambda_l1': 0.0006388863752727577, 'lambda_l2': 0.046230648892369545}. Best is trial 42 with value: 0.871256308394161.
# regularization_factors, val_score: 0.871365:  20%|##        | 4/20 [00:08<00:32,  2.03s/it][I 2020-08-27 08:43:32,528] Trial 43 finished with value: 0.8711950979768645 and parameters: {'lambda_l1': 0.000828997748988019, 'lambda_l2': 0.029439352624064954}. Best is trial 42 with value: 0.871256308394161.
# regularization_factors, val_score: 0.871365:  25%|##5       | 5/20 [00:10<00:30,  2.00s/it][I 2020-08-27 08:43:34,456] Trial 44 finished with value: 0.8708892634566672 and parameters: {'lambda_l1': 0.0012578217213391402, 'lambda_l2': 0.038601230991605694}. Best is trial 42 with value: 0.871256308394161.
# regularization_factors, val_score: 0.871365:  30%|###       | 6/20 [00:11<00:27,  1.99s/it][I 2020-08-27 08:43:36,430] Trial 45 finished with value: 0.871105590676149 and parameters: {'lambda_l1': 0.00045763648019387894, 'lambda_l2': 0.029476433892061758}. Best is trial 42 with value: 0.871256308394161.
# regularization_factors, val_score: 0.871365:  35%|###5      | 7/20 [00:14<00:29,  2.26s/it][I 2020-08-27 08:43:39,300] Trial 46 finished with value: 0.8699648906385816 and parameters: {'lambda_l1': 0.003643067334507628, 'lambda_l2': 5.034706099991099}. Best is trial 42 with value: 0.871256308394161.
# regularization_factors, val_score: 0.871365:  40%|####      | 8/20 [00:16<00:25,  2.14s/it][I 2020-08-27 08:43:41,161] Trial 47 finished with value: 0.8713639824797584 and parameters: {'lambda_l1': 1.9746443129913707e-08, 'lambda_l2': 4.1382670734930084e-07}. Best is trial 47 with value: 0.8713639824797584.
# regularization_factors, val_score: 0.871365:  45%|####5     | 9/20 [00:18<00:22,  2.08s/it][I 2020-08-27 08:43:43,094] Trial 48 finished with value: 0.8713639824797584 and parameters: {'lambda_l1': 2.8557008850646123e-08, 'lambda_l2': 2.1672665593797102e-08}. Best is trial 47 with value: 0.8713639824797584.
# regularization_factors, val_score: 0.871365:  50%|#####     | 10/20 [00:20<00:20,  2.03s/it][I 2020-08-27 08:43:45,008] Trial 49 finished with value: 0.871365325022938 and parameters: {'lambda_l1': 1.7354621856294035e-08, 'lambda_l2': 1.7482845601246716e-08}. Best is trial 49 with value: 0.871365325022938.
# regularization_factors, val_score: 0.871365:  55%|#####5    | 11/20 [00:22<00:17,  2.00s/it][I 2020-08-27 08:43:46,934] Trial 50 finished with value: 0.8713639824797584 and parameters: {'lambda_l1': 1.2544788683850441e-08, 'lambda_l2': 2.0592368076696724e-08}. Best is trial 49 with value: 0.871365325022938.
# regularization_factors, val_score: 0.871365:  60%|######    | 12/20 [00:24<00:15,  1.98s/it][I 2020-08-27 08:43:48,860] Trial 51 finished with value: 0.8713633112081687 and parameters: {'lambda_l1': 1.5985894425113856e-08, 'lambda_l2': 2.5753666462507646e-08}. Best is trial 49 with value: 0.871365325022938.
# regularization_factors, val_score: 0.871365:  65%|######5   | 13/20 [00:26<00:13,  1.96s/it][I 2020-08-27 08:43:50,777] Trial 52 finished with value: 0.8713639824797584 and parameters: {'lambda_l1': 1.7633185544230298e-08, 'lambda_l2': 1.8642617957155582e-08}. Best is trial 49 with value: 0.871365325022938.
# regularization_factors, val_score: 0.871365:  70%|#######   | 14/20 [00:28<00:11,  1.95s/it][I 2020-08-27 08:43:52,702] Trial 53 finished with value: 0.871365325022938 and parameters: {'lambda_l1': 1.8101466784141216e-06, 'lambda_l2': 1.0990261146926967e-08}. Best is trial 49 with value: 0.871365325022938.
# regularization_factors, val_score: 0.871365:  75%|#######5  | 15/20 [00:30<00:09,  1.95s/it][I 2020-08-27 08:43:54,644] Trial 54 finished with value: 0.8713639824797584 and parameters: {'lambda_l1': 1.7518084027507273e-06, 'lambda_l2': 1.6497418104399926e-06}. Best is trial 49 with value: 0.871365325022938.
# regularization_factors, val_score: 0.871365:  80%|########  | 16/20 [00:32<00:07,  1.96s/it][I 2020-08-27 08:43:56,644] Trial 55 finished with value: 0.8712235089499208 and parameters: {'lambda_l1': 3.102536852051813e-06, 'lambda_l2': 2.127382448751673e-06}. Best is trial 49 with value: 0.871365325022938.
# regularization_factors, val_score: 0.871509:  85%|########5 | 17/20 [00:34<00:05,  1.97s/it][I 2020-08-27 08:43:58,618] Trial 56 finished with value: 0.8715086454872255 and parameters: {'lambda_l1': 0.6656824658681227, 'lambda_l2': 1.0462792232272305e-08}. Best is trial 56 with value: 0.8715086454872255.
# regularization_factors, val_score: 0.871509:  90%|######### | 18/20 [00:38<00:05,  2.65s/it][I 2020-08-27 08:44:02,856] Trial 57 finished with value: 0.8611916468979836 and parameters: {'lambda_l1': 7.52820786463276, 'lambda_l2': 1.6875389132141317e-07}. Best is trial 56 with value: 0.8715086454872255.
# regularization_factors, val_score: 0.871509:  95%|#########5| 19/20 [00:40<00:02,  2.44s/it][I 2020-08-27 08:44:04,796] Trial 58 finished with value: 0.8712321983351244 and parameters: {'lambda_l1': 7.755976648491387e-07, 'lambda_l2': 1.845334501475948e-05}. Best is trial 56 with value: 0.8715086454872255.
# regularization_factors, val_score: 0.871509: 100%|##########| 20/20 [00:42<00:00,  2.29s/it][I 2020-08-27 08:44:06,731] Trial 59 finished with value: 0.8711466019210624 and parameters: {'lambda_l1': 4.608348399359139e-06, 'lambda_l2': 2.6265218134123476e-05}. Best is trial 56 with value: 0.8715086454872255.
# regularization_factors, val_score: 0.871509: 100%|##########| 20/20 [00:42<00:00,  2.11s/it]
# min_data_in_leaf, val_score: 0.871509:  20%|##        | 1/5 [00:02<00:09,  2.33s/it][I 2020-08-27 08:44:09,067] Trial 60 finished with value: 0.8639738527245521 and parameters: {'min_child_samples': 100}. Best is trial 60 with value: 0.8639738527245521.
# min_data_in_leaf, val_score: 0.871509:  40%|####      | 2/5 [00:04<00:06,  2.23s/it][I 2020-08-27 08:44:11,049] Trial 61 finished with value: 0.8703775289792324 and parameters: {'min_child_samples': 50}. Best is trial 61 with value: 0.8703775289792324.
# min_data_in_leaf, val_score: 0.871509:  60%|######    | 3/5 [00:06<00:04,  2.16s/it][I 2020-08-27 08:44:13,059] Trial 62 finished with value: 0.8710830327668359 and parameters: {'min_child_samples': 10}. Best is trial 62 with value: 0.8710830327668359.
# min_data_in_leaf, val_score: 0.871509:  80%|########  | 4/5 [00:08<00:02,  2.12s/it][I 2020-08-27 08:44:15,087] Trial 63 finished with value: 0.871330875258821 and parameters: {'min_child_samples': 25}. Best is trial 63 with value: 0.871330875258821.
# min_data_in_leaf, val_score: 0.871509: 100%|##########| 5/5 [00:10<00:00,  2.10s/it][I 2020-08-27 08:44:17,127] Trial 64 finished with value: 0.8708343783811493 and parameters: {'min_child_samples': 5}. Best is trial 63 with value: 0.871330875258821.
# min_data_in_leaf, val_score: 0.871509: 100%|##########| 5/5 [00:10<00:00,  2.08s/it]
#   Params:
#     objective: binary
#     metric: auc
#     random_state: 22
#     learning_rate: 0.01
#     lambda_l1: 0.6656824658681227
#     lambda_l2: 1.0462792232272305e-08
#     num_leaves: 24
#     feature_fraction: 0.4
#     bagging_fraction: 1.0
#     bagging_freq: 0
#     min_child_samples: 20

# %%
#evaluation_results = {}

#clf = lgb.train(
#    train_set=train_data,
#    params=tuner.best_params,
#    valid_sets=[train_data, test_data], 
#    valid_names=['Train', 'Test'],
#    evals_result=evaluation_results,
#    num_boost_round=1000,
#    early_stopping_rounds=100,
#    verbose_eval=100
#)
#optimum_boost_rounds = clf.best_iteration

#print('Result:')
#print(clf.params)
#print(clf.best_score)

# %% [markdown]
# ## 可視化

# %%
#fig, axs = plt.subplots(1, 2, figsize=[15, 4])

# Plot the log loss during training
#axs[0].plot(evaluation_results['Train']['auc'], label='Train')
#axs[0].plot(evaluation_results['Test']['auc'], label='Test')
#axs[0].set_ylabel('AUC')
#axs[0].set_xlabel('Boosting round')
#axs[0].set_title('Training performance')
#axs[0].legend()

# Plot feature importance
#importances = pd.DataFrame({'features': cv_booster.feature_name(), 
#                            'importance': cv_booster.feature_importance()}).sort_values('importance', ascending=False)
#axs[1].bar(x=np.arange(len(importances)), height=importances['importance'])
#axs[1].set_xticks(np.arange(len(importances)))
#axs[1].set_xticklabels(importances['features'], rotation = 45)
#axs[1].set_ylabel('Feature importance (# times used to split)')
#axs[1].set_title('Feature importance')

#plt.show()

# %%
#importances.sort_values('importance')

# %%
preds = np.round(cv_booster.predict(p_train_df)).mean(axis=0)
y_pred = np.where(preds > 0.5, 1, 0)
print('Accuracy score = \t {}'.format(accuracy_score(y, y_pred)))
print('Precision score = \t {}'.format(precision_score(y, y_pred)))
print('Recall score =   \t {}'.format(recall_score(y, y_pred)))
print('F1 score =      \t {}'.format(f1_score(y, y_pred)))
# Out:
# Accuracy score = 	 0.9213584905660377
# Precision score = 	 0.8654434250764526
# Recall score =   	 0.37236842105263157
# F1 score =      	 0.5206991720331187

# %%
fpr, tpr, thresholds = roc_curve(y, preds)
auc_score = auc(fpr, tpr)
print(auc_score)
# Out:
# 0.7311515681787589

# %%
# ROC曲線をプロット
plt.plot(fpr, tpr, label='ROC curve (area = %.2f)'%auc_score)
plt.legend()
plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)

# %% [markdown]
# ## 推論

# %%
test_pred = np.array(cv_booster.predict(p_test_df, num_iteration=cv_booster.best_iteration)).mean(axis=0)

# %%
#submit_df[1] = test_pred
#submit_df.to_csv('submit-lg.csv', header=False, index=False)

# %%
#submit_df.head()

# %%
#pseudo labeling

plt.hist(test_pred, bins=30)
# Out:
# (array([5.578e+03, 9.407e+03, 5.477e+03, 5.017e+03, 4.264e+03, 2.842e+03,
#         1.895e+03, 1.170e+03, 8.090e+02, 6.450e+02, 4.250e+02, 2.740e+02,
#         2.180e+02, 1.460e+02, 1.320e+02, 7.700e+01, 5.900e+01, 3.400e+01,
#         2.800e+01, 1.100e+01, 5.000e+00, 4.000e+00, 1.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 2.000e+00]),
#  array([0.00654904, 0.03131068, 0.05607231, 0.08083394, 0.10559557,
#         0.13035721, 0.15511884, 0.17988047, 0.2046421 , 0.22940374,
#         0.25416537, 0.278927  , 0.30368863, 0.32845027, 0.3532119 ,
#         0.37797353, 0.40273516, 0.4274968 , 0.45225843, 0.47702006,
#         0.50178169, 0.52654333, 0.55130496, 0.57606659, 0.60082822,
#         0.62558986, 0.65035149, 0.67511312, 0.69987475, 0.72463639,
#         0.74939802]),
#  <BarContainer object of 30 artists>)

# %%
test_pred_df = pd.DataFrame(test_pred)

border = round(1 - y.sum() / y.count(), 2)
border
# Out:
# 0.89

# %%
percentile_list = [.01, .25, .5, .75, border]
test_pred_df.describe(percentile_list)
# Out:
#                   0
# count  38525.000000
# mean       0.093175
# std        0.070973
# min        0.006549
# 1%         0.013380
# 25%        0.039647
# 50%        0.075040
# 75%        0.124747
# 89%        0.176740
# max        0.749398

# %%
pred_border = float(test_pred_df.quantile(border))
pred_border
# Out:
# 0.17674047399100895

# %%
round_test_pred = np.array(list(map(lambda x: 0 if x < pred_border else 1, test_pred)))
round_test_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
round(1 - round_test_pred.sum() / len(round_test_pred), 2)
# Out:
# 0.89

# %%
p_test_df['poutcome'] = round_test_pred
p_train_df['poutcome'] = y

p_train_df['y'] = py
p_test_df['y'] = pz

p_train_df.fillna(-1, inplace=True)
p_test_df.fillna(-1, inplace=True)

# %%
df_dict = {}
for name, group in pd.concat([p_train_df, p_test_df]).groupby('y'):
    df_dict[name] = group
    
y_train_df = pd.concat([df_dict[0], df_dict[1]])
y_test_df = df_dict[-1]

y_test_df.drop(['y'], axis=1, inplace=True)

# %%
y_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27100 entries, 8 to 27062
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        27100 non-null  int64
#  1   job        27100 non-null  int64
#  2   marital    27100 non-null  int64
#  3   education  27100 non-null  int64
#  4   housing    27100 non-null  int64
#  5   loan       27100 non-null  int64
#  6   contact    27100 non-null  int64
#  7   day        27100 non-null  int64
#  8   month      27100 non-null  int64
#  9   duration   27100 non-null  int64
#  10  campaign   27100 non-null  int64
#  11  previous   27100 non-null  int64
#  12  days       27100 non-null  uint16
#  13  poutcome   27100 non-null  int64
#  14  y          27100 non-null  float64
# dtypes: float64(1), int64(13), uint16(1)
# memory usage: 3.2 MB

# %%
y_test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18050 entries, 0 to 18049
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        18050 non-null  int64
#  1   job        18050 non-null  int64
#  2   marital    18050 non-null  int64
#  3   education  18050 non-null  int64
#  4   housing    18050 non-null  int64
#  5   loan       18050 non-null  int64
#  6   contact    18050 non-null  int64
#  7   day        18050 non-null  int64
#  8   month      18050 non-null  int64
#  9   duration   18050 non-null  int64
#  10  campaign   18050 non-null  int64
#  11  previous   18050 non-null  int64
#  12  days       18050 non-null  uint16
#  13  poutcome   18050 non-null  int64
# dtypes: int64(13), uint16(1)
# memory usage: 2.0 MB

# %%
y_train_df.to_csv('y_train.csv', index=False)
y_test_df.to_csv('y_test.csv', index=False)

# %%
y_train_df['poutcome'].value_counts()
# Out:
# 0    24060
# 1     3040
# Name: poutcome, dtype: int64

# %%
y_test_df['poutcome'].value_counts()
# Out:
# 0    16092
# 1     1958
# Name: poutcome, dtype: int64
